# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/bsiddan25/program/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
#
# My lane is the content refresh opportunity. This would belong to the scoring/ranking type. The goal is to score and rank the pages according to which needs to be refreshed first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import pandas as pd

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
#
# The model would be predicting which pages are likely to decline. This is a proxy label as I am actually interested in which pages need to be refreshed. Knowing which pages decline is a good indicator but does not always equal need for refresh, so it is a proxy. The label will be derived  from an observed outcome in the dataset, which is trend_direction. If trend_direction is down, then is_declining label is 1, else it is zero.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
#
# An ideal success metric would be one that is able to measure the consequent improvement of performance for the page after the refresh, so things like increased click through rates, increase in impressions, etc. However, the data after the page has been refreshed is not avaliable. So Precision@20 would be a good metric to use. But I could also conduct a kind of historical backtesting experiment, where I use my model at an earlier point in time and see if it would have identified the pages that subsequently declined.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*
#
# One row is one web page/content item identified by content_id.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.


import os
import sys
import subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(
            ["git", "clone", "--depth", "1", REPO_URL, REPO_DIR],
            check=True
        )

    os.chdir(REPO_DIR)

    subprocess.run(
        [sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"],
        check=True
    )

elif os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")

import pandas as pd
import numpy as np

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print(f"Dataset shape: {df.shape}")
print(f"Number of rows: {len(df)}")

print("Columns in the dataset:")
print(df.columns.tolist())

df.head()

print("Each row represents one page/content item.")
print(f"Number of page records: {len(df)}")

display(df.head(10))

df["is_declining_label"] = (
    df["trend_direction"] == "down"
).astype(int)

display(
    df[
        ["trend_direction", "is_declining_label"]
    ].head(20)
)

print("Proxy target distribution:")
print(df["is_declining_label"].value_counts())

print("\nProxy target proportions:")
print(df["is_declining_label"].value_counts(normalize=True))

target_summary = pd.DataFrame({
    "count": df["is_declining_label"].value_counts(),
    "percentage": df["is_declining_label"].value_counts(normalize=True) * 100
})

display(target_summary)

lane_columns = [
    "content_id",
    "content_age_days",
    "days_since_last_update",
    "impressions_90d",
    "avg_position",
    "ctr",
    "word_count",
    "trend_direction",
    "is_declining_label"
]

lane_df = df[lane_columns].copy()

display(lane_df.head(10))
# Out:
# Dataset shape: (30000, 44)
# Number of rows: 30000
# Columns in the dataset:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']
# Each row represents one page/content item.
# Number of page records: 30000
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
#
# A fixed rule uses a manual chosen threshold. ML can learn relationships and interactions among multiple page-level signals and produce a more flexible ranking.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
